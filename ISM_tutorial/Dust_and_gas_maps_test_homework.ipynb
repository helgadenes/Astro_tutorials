# %% [markdown]
# <a href="https://colab.research.google.com/github/helgadenes/Astrophysics_yachay/blob/main/python_tutorials/ISM_tutorial/Dust_and_gas_maps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dust and gas maps
#
# Documentation on dust maps: https://dustmaps.readthedocs.io/en/latest/installation.html
#
# More info on dust maps: http://argonaut.skymaps.info/usage
#
# This tutorial
# - gets E(B-V) from dust maps
# - converts E(B-V) to $A_V$
# - plots the dust maps
# - downloads a neutral hydrogen column density map for the same region N(HI)
# - compares the two data sets.
#
# Documentation on skyview: https://astroquery.readthedocs.io/en/latest/skyview/skyview.html

# %%
# astroquery and dustmaps are not a default package in google colab
# !pip install astroquery
# !pip install dustmaps
# Out:
# Collecting astroquery
#   Downloading astroquery-0.4.7-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from astroquery) (1.26.4)
# Requirement already satisfied: astropy>=4.2.1 in /usr/local/lib/python3.10/dist-packages (from astroquery) (6.1.4)
# Requirement already satisfied: requests>=2.19 in /usr/local/lib/python3.10/dist-packages (from astroquery) (2.32.3)
# Requirement already satisfied: beautifulsoup4>=4.8 in /usr/local/lib/python3.10/dist-packages (from astroquery) (4.12.3)
# Requirement already satisfied: html5lib>=0.999 in /usr/local/lib/python3.10/dist-packages (from astroquery) (1.1)
# Requirement already satisfied: keyring>=15.0 in /usr/lib/python3/dist-packages (from astroquery) (23.5.0)
# Collecting pyvo>=1.1 (from astroquery)
#   Downloading pyvo-1.5.3-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.10/dist-packages (from astropy>=4.2.1->astroquery) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.8.27.10.28.29 in /usr/local/lib/python3.10/dist-packages (from astropy>=4.2.1->astroquery) (0.2024.10.7.0.32.46)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.10/dist-packages (from astropy>=4.2.1->astroquery) (6.0.2)
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.10/dist-packages (from astropy>=4.2.1->astroquery) (24.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.8->astroquery) (2.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=0.999->astroquery) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=0.999->astroquery) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19->astroquery) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19->astroquery) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19->astroquery) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19->astroquery) (2024.8.30)
# Downloading astroquery-0.4.7-py3-none-any.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 32.4 MB/s eta 0:00:00
# Downloading pyvo-1.5.3-py3-none-any.whl (912 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 912.9/912.9 kB 28.9 MB/s eta 0:00:00
# Installing collected packages: pyvo, astroquery
# Successfully installed astroquery-0.4.7 pyvo-1.5.3
# Collecting dustmaps
#   Downloading dustmaps-1.0.13-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: astropy in /usr/local/lib/python3.10/dist-packages (from dustmaps) (6.1.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from dustmaps) (3.11.0)
# Collecting healpy (from dustmaps)
#   Downloading healpy-1.17.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.9 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from dustmaps) (1.26.4)
# Requirement already satisfied: progressbar2 in /usr/local/lib/python3.10/dist-packages (from dustmaps) (4.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from dustmaps) (2.32.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from dustmaps) (1.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from dustmaps) (1.16.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.10/dist-packages (from astropy->dustmaps) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.8.27.10.28.29 in /usr/local/lib/python3.10/dist-packages (from astropy->dustmaps) (0.2024.10.7.0.32.46)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.10/dist-packages (from astropy->dustmaps) (6.0.2)
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.10/dist-packages (from astropy->dustmaps) (24.1)
# Requirement already satisfied: python-utils>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from progressbar2->dustmaps) (3.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->dustmaps) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->dustmaps) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->dustmaps) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->dustmaps) (2024.8.30)
# Requirement already satisfied: typing-extensions>3.10.0.2 in /usr/local/lib/python3.10/dist-packages (from python-utils>=3.8.1->progressbar2->dustmaps) (4.12.2)
# Downloading dustmaps-1.0.13-py3-none-any.whl (750 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.6/750.6 kB 5.5 MB/s eta 0:00:00
# Downloading healpy-1.17.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 35.0 MB/s eta 0:00:00
# Installing collected packages: healpy, dustmaps
# Successfully installed dustmaps-1.0.13 healpy-1.17.3

# %% [markdown]
# ## Plotting maps
#
# Dustmaps provides a unified interface for several 2D and 3D maps of interstellar dust reddening and extinction.
#
# Documentation on how to use dust maps:
# https://dustmaps.readthedocs.io/en/latest/examples.html

# %% [markdown]
# ## Doing a Web based Query to get dust maps

# %%
from __future__ import print_function

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# astropy libraries
import astropy.units as u
from astropy.coordinates import SkyCoord
from astroquery.skyview import SkyView
from astropy.wcs import WCS

# dustmaps libraries
from dustmaps.sfd import SFDWebQuery
from dustmaps.bayestar import BayestarWebQuery

# %%
# test query for a single coordinate

coords = SkyCoord(119.*u.deg, 3.*u.deg, distance=1000.*u.pc, frame='galactic')

bayestar_0 = BayestarWebQuery()

Av_bayesta_0 = 2.742 * bayestar_0(coords)

print('Av from Baystar dust map:', Av_bayesta_0)
# Out:
# Response received from server:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
# <title>500 Internal Server Error</title>
# <h1>Internal Server Error</h1>
# <p>The server encountered an internal error and was unable to complete your request.  Either the server is overloaded or there is an error in the application.</p>
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       3 coords = SkyCoord(119.*u.deg, 3.*u.deg, distance=1000.*u.pc, frame='galactic')
#       5 bayestar_0 = BayestarWebQuery()
# ----> 7 Av_bayesta_0 = 2.742 * bayestar_0(coords)
#       9 print('Av from Baystar dust map:', Av_bayesta_0)
#
# File /opt/anaconda3/lib/python3.8/site-packages/dustmaps/map_base.py:112, in ensure_coord_type.<locals>._wrapper_func(self, coords, **kwargs)
#     110 if not isinstance(coords, coordinates.SkyCoord):
#     111     raise TypeError('`coords` must be an astropy.coordinates.SkyCoord object.')
# --> 112 return f(self, coords, **kwargs)
#
# File /opt/anaconda3/lib/python3.8/site-packages/dustmaps/map_base.py:512, in WebDustMap.__call__(self, coords, **kwargs)
#     507 @ensure_coord_type
#     508 def __call__(self, coords, **kwargs):
#     509     """
#     510     An alias for :obj:`WebDustMap.query()`.
#     511     """
# --> 512     return self.query(coords, **kwargs)
#
# File /opt/anaconda3/lib/python3.8/site-packages/dustmaps/map_base.py:112, in ensure_coord_type.<locals>._wrapper_func(self, coords, **kwargs)
#     110 if not isinstance(coords, coordinates.SkyCoord):
#     111     raise TypeError('`coords` must be an astropy.coordinates.SkyCoord object.')
# --> 112 return f(self, coords, **kwargs)
#
# File /opt/anaconda3/lib/python3.8/site-packages/dustmaps/map_base.py:359, in web_api_method.<locals>.decorator.<locals>.api_wrapper(self, *args, **kwargs)
#     357     print('Response received from server:')
#     358     print(r.text)
# --> 359     raise err
#     361 # Deserialize the response
#     362 return json.loads(r.text, cls=decoder)
#
# File /opt/anaconda3/lib/python3.8/site-packages/dustmaps/map_base.py:355, in web_api_method.<locals>.decorator.<locals>.api_wrapper(self, *args, **kwargs)
#     350 r = requests.post(
#     351     self.base_url.rstrip('/') + '/' + url.lstrip('/'),
#     352     data=data,
#     353     headers=headers)
#     354 try:
# --> 355     r.raise_for_status()
#     356 except requests.exceptions.HTTPError as err:
#     357     print('Response received from server:')
#
# File /opt/anaconda3/lib/python3.8/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 500 Server Error: INTERNAL SERVER ERROR for url: http://argonaut.skymaps.info/api/v2/bayestar2019/query

# %% [markdown]
# Identifying regions of interest in the Galaxy is easyest in galactic coordinates. However for the comparison with the other data it is better to use equatorial coordinates. You can use the SkyCoord packages to convert between the two coordinate systems.

# %%
# Converting coordinates for the edge of the Aql south molecular cloud

# galactic coordinates:
c_g = SkyCoord(l=37 * u.degree, b=-3 * u.degree, frame='galactic')


#c_g = SkyCoord(ra=73 * u.degree, dec=3 * u.degree, frame='icrs')

# equatorial coordinates:
c_g.icrs
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (287.38728563, 2.24578767)>

# %%
SkyCoord('05h14m32.27210s', '−08d12m05.8981s', frame='icrs')
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (78.63446708, -8.20163836)>

# %%
# let's define a square region for the dust map in equatorial coordinates
# this is an 8 x 8 deg region of the sky

ra0, dec0 = (287., 3.)
ra = np.arange(ra0 - 4., ra0 + 4., 0.05)
dec = np.arange(dec0 - 4., dec0 + 4., 0.05)
ra, dec = np.meshgrid(ra, dec)
coords = SkyCoord(ra * u.deg, dec * u.deg, distance=1. * u.kpc, frame='icrs')

# %%
# downloading 2 different maps for the same region of the sky
# and converting the E(B-V) reddening to A_v extinction

sfd = SFDWebQuery()

# convert E(B-V) to A_v
Av_sfd = 2.742 * sfd(coords)

bayestar = BayestarWebQuery()

# convert E(B-V) to A_v
Av_bayestar = 2.742 * bayestar(coords)

# %%
# plotting the two maps that we downloaded

fig = plt.figure(figsize=(12,4), dpi=150)

for k,(Av,title) in enumerate([(Av_sfd, 'SFD'),
                               (Av_bayestar, 'Bayestar')]):
    ax = fig.add_subplot(1,3,k+1)
    ax.imshow(
        np.sqrt(Av)[::,::-1],
        vmin=0.,
        vmax=2.,
        origin='lower',
        interpolation='nearest',
        cmap='binary',
        aspect='equal'
    )
    ax.axis('off')
    ax.set_title(title)

fig.subplots_adjust(wspace=0., hspace=0.)
plt.savefig('comparison.png', dpi=150)

# %% [markdown]
# **Which dust maps looks higher resolution?**

# %%
Av.shape
# Out:
# (160, 160)

# %% [markdown]
# ## HI column denisty map
#
# We want to compare the dust maps with HI column denisty maps. For this, we need to download HI data.
#
# Currently, the best data set available for the whole sky is HI4PI, which is available from Skyview. SkyView is a multi-wavelength data base: https://skyview.gsfc.nasa.gov/current/cgi/titlepage.pl You can downolad optical, infrared, UV, radio, etc. images from
#
# SkyView. SkyView also has a python interface: https://astroquery.readthedocs.io/en/latest/skyview/skyview.html (This website lists all the available data sets.)
#
#
# Important, **you need to make sure to download the HI data at the same coordinates with the same pixel resolution as the dust maps data!** The dust maps do not have metadata.

# %%
# get HI column denisty map for the same region of the sky

c = SkyCoord(ra=287 * u.degree, dec=3 * u.degree, frame='icrs')

path = SkyView.get_images(position=c, width=8*u.deg, height=8*u.deg, survey=['HI4PI'], pixels=[160,160])

hdulist_HI = path[0]
d_HI = hdulist_HI[0].data
h_HI = hdulist_HI[0].header
# Out:
# WARNING: AstropyDeprecationWarning: The truth value of a Quantity is ambiguous. In the future this will raise a ValueError. [astropy.units.quantity]

# %%
d_HI
# Out:
# array([[1.7429602e+21, 1.7459804e+21, 1.7496981e+21, ..., 1.2096363e+22,
#         1.2514239e+22, 1.2926002e+22],
#        [1.7678735e+21, 1.7641091e+21, 1.7637650e+21, ..., 1.2233429e+22,
#         1.2671097e+22, 1.3101916e+22],
#        [1.7916096e+21, 1.7804867e+21, 1.7748574e+21, ..., 1.2329642e+22,
#         1.2790638e+22, 1.3238806e+22],
#        ...,
#        [3.5652161e+21, 3.5881290e+21, 3.6074407e+21, ..., 6.9763320e+21,
#         6.8707653e+21, 6.7535879e+21],
#        [3.5182300e+21, 3.5353713e+21, 3.5482235e+21, ..., 6.9033320e+21,
#         6.7958328e+21, 6.6748481e+21],
#        [3.4823440e+21, 3.4951542e+21, 3.5030068e+21, ..., 6.8527453e+21,
#         6.7398969e+21, 6.6107314e+21]], dtype=float32)

# %%
# Let's plot the HI data

fig = plt.figure(figsize=(11,10))
ax = fig.add_subplot(1,1,1, projection=WCS(h_HI))
ax.imshow(d_HI, vmax=np.percentile(d_HI, 99.8))
ax.set_xlabel('RA', size=18,family='serif')
ax.set_ylabel('Dec', size=18,family='serif')
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)

plt.show()

# %% [markdown]
# ## Compare the dust and the gas data
#
# The two data sets should show a liner correlation. The more dust we have in a region, the more N(HI) we expect.
#
# Note, it is importnat to match the two 2D arrays. To check that the two arrays are aligned, we will plot the images and make an overlay.

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
plt.imshow(Av)
ax1.invert_yaxis()

ax2 = fig.add_subplot(1,2,2)
plt.imshow(d_HI)
ax2.invert_yaxis()

plt.show()

# %% [markdown]
# **Does this look right?**
#
# The orientation of the two images does not match!

# %%
# lets make the two images match. We need to reverse the RA direction for the dust map

Av2 = Av[:, ::-1]

fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
plt.imshow(Av2)
ax1.invert_yaxis()

ax2 = fig.add_subplot(1,2,2)
plt.imshow(d_HI)
ax2.invert_yaxis()

plt.show()

# %% [markdown]
# **Do the maps look the same now?**
#
# **What could be the reason for differences?**

# %% [markdown]
# ### Lets make a better comparison with an overlay of the dust map with N(HI) contours

# %%
# making an overlay

fig = plt.figure(figsize=(6,5))
ax = fig.add_subplot(1,1,1)
ax.imshow(Av2)
ax.contour(d_HI, levels=10, cmap='Oranges')
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
ax.invert_yaxis()
plt.show()

# %% [markdown]
# **How is the match between the two datasets?**

# %% [markdown]
# ### Comparing the E(B-V) to the N(HI) data

# %%
# directly compare the E(B-V) to N(HI) in each pixel

fig = plt.figure(figsize=(6,5))
ax = fig.add_subplot(1,1,1)
plt.scatter(Av2, d_HI)
ax.set_xlabel('E(B-V) [mag]', size=18,family='serif')
ax.set_ylabel(r'N(HI) [atoms/cm$^2$]', size=18,family='serif')
plt.show()

# %%
# lets add a model from a scientic paper
# relation from Güver and Özel 2009 (doi:10.1111/j.1365-2966.2009.15598.x)

ebv_range = np.arange(np.min(Av), np.max(Av), 0.1)
line = ebv_range * 2.2 * 10**21

fig = plt.figure(figsize=(6,5))
ax = fig.add_subplot(1,1,1)
plt.scatter(Av2, d_HI)
plt.plot(ebv_range, line, color='C1')
ax.set_xlabel('E(B-V) [mag]', size=18,family='serif')
ax.set_ylabel(r'N(HI) [atoms/cm$^2$]', size=18,family='serif')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 4
#       1 # lets add a model from a scientic paper
#       2 # relation from Güver and Özel 2009 (doi:10.1111/j.1365-2966.2009.15598.x)
# ----> 4 ebv_range = np.arange(np.min(Av), np.max(Av), 0.1)
#       5 line = ebv_range * 2.2 * 10**21
#       7 fig = plt.figure(figsize=(6,5))
#
# ValueError: arange: cannot compute length

# %% [markdown]
# The model seems to fit the data at small E(B-V) but not at higher values. Where the HI column density becomes less then expected.
#
# ## What is the reason of the discrepancy?
